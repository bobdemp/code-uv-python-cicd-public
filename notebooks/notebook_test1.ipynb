# %%
import sys

from importlib.metadata import distributions

# This information is for when developing.

print(sys.version)

# Collect (name, version) tuples
packages = [(dist.metadata["Name"], dist.version) for dist in distributions()]

# Sort by package name
packages.sort(key=lambda x: x[0].lower())

# Print
for name, version in packages:
    print(name, version)
# Out:
# 3.10.18 (main, Jan 12 2026, 14:03:48) [Clang 17.0.0 (clang-1700.6.3.2)]
# annotated-types 0.7.0
# appnope 0.1.4
# asn1crypto 1.5.1
# asttokens 3.0.1
# backports.tarfile 1.2.0
# boto3 1.42.30
# botocore 1.42.30
# certifi 2026.1.4
# cffi 2.0.0
# cfgv 3.5.0
# chardet 5.2.0
# charset-normalizer 3.4.4
# click 8.3.1
# cloudpickle 3.1.1
# colorama 0.4.6
# comm 0.2.3
# cryptography 46.0.3
# debugpy 1.8.19
# decorator 5.2.1
# diff_cover 10.2.0
# distlib 0.4.0
# exceptiongroup 1.3.1
# executing 2.2.1
# filelock 3.20.3
# identify 2.6.16
# idna 3.11
# importlib_metadata 8.7.1
# iniconfig 2.3.0
# ipykernel 6.28.0
# ipython 8.38.0
# jaraco.classes 3.4.0
# jaraco.context 6.1.0
# jaraco.functools 4.4.0
# jedi 0.19.2
# Jinja2 3.1.6
# jmespath 1.0.1
# jupyter_client 8.8.0
# jupyter_core 5.9.1
# keyring 25.7.0
# MarkupSafe 3.0.3
# matplotlib-inline 0.2.1
# more-itertools 10.8.0
# nest-asyncio 1.6.0
# nodeenv 1.10.0
# packaging 25.0
# parso 0.8.5
# pathspec 1.0.3
# pexpect 4.9.0
# pip 25.3
# platformdirs 4.5.1
# pluggy 1.6.0
# pre_commit 4.5.1
# prompt_toolkit 3.0.52
# protobuf 5.29.3
# psutil 7.2.1
# ptyprocess 0.7.0
# pure_eval 0.2.3
# pycparser 2.23
# pydantic 2.12.5
# pydantic_core 2.41.5
# Pygments 2.19.2
# PyJWT 2.10.1
# pyOpenSSL 25.3.0
# pytest 9.0.2
# python-dateutil 2.9.0.post0
# pytz 2025.2
# PyYAML 6.0.3
# pyzmq 27.1.0
# regex 2026.1.15
# requests 2.32.5
# s3transfer 0.16.0
# setuptools 80.9.0
# six 1.17.0
# snowflake 1.9.0
# snowflake-connector-python 4.2.0
# snowflake-snowpark-python 1.44.0
# snowflake._legacy 1.0.2
# snowflake.core 1.9.0
# sortedcontainers 2.4.0
# sqlfluff 4.0.0
# stack-data 0.6.3
# tblib 3.2.2
# tomli 2.4.0
# tomlkit 0.14.0
# tornado 6.5.4
# tqdm 4.67.1
# traitlets 5.14.3
# typing-inspection 0.4.2
# typing_extensions 4.15.0
# tzlocal 5.3.1
# urllib3 2.6.3
# virtualenv 20.36.1
# wcwidth 0.2.14
# wheel 0.46.3
# zipp 3.23.0
